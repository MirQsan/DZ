# %% [markdown]
# # Оформление

# %% [markdown]
# *Библиотеки*

# %%
import matplotlib.pyplot as plt
import matplotlib.path as mpltPath
import numpy as np
import itertools
import random
import math
import functools

# %% [markdown]
# 2.1

# %%
def gen_rectangle(n = 10):
    o = []
    x = np.array([0, 0, 1, 1, 0])
    y = np.array([0, 2, 2, 0, 0])
    for i in range(n):
        plt.plot(x, y)
        plt.fill_between(x, y)
        o.append(list(zip(x,y)))
        x += 2
    plt.show()
    return o
    
gen_rectangle()
# Out:
# [[(0, 0), (0, 2), (1, 2), (1, 0), (0, 0)],
#  [(2, 0), (2, 2), (3, 2), (3, 0), (2, 0)],
#  [(4, 0), (4, 2), (5, 2), (5, 0), (4, 0)],
#  [(6, 0), (6, 2), (7, 2), (7, 0), (6, 0)],
#  [(8, 0), (8, 2), (9, 2), (9, 0), (8, 0)],
#  [(10, 0), (10, 2), (11, 2), (11, 0), (10, 0)],
#  [(12, 0), (12, 2), (13, 2), (13, 0), (12, 0)],
#  [(14, 0), (14, 2), (15, 2), (15, 0), (14, 0)],
#  [(16, 0), (16, 2), (17, 2), (17, 0), (16, 0)],
#  [(18, 0), (18, 2), (19, 2), (19, 0), (18, 0)]]

# %% [markdown]
# 2.2

# %%
def gen_triangle(n = 10):
    #((0, 0), (0.5, 2), (1, 0))
    o = []
    x = np.array([0, 0.5, 1, 0])
    y = np.array([0, 2, 0, 0])
    for i in range(n):
        plt.plot(x, y)
        plt.fill_between(x, y)
        o.append(list(zip(x, y)))
        x += 2
    plt.show
    return o
    
gen_triangle()
# Out:
# [[(0.0, 0), (0.5, 2), (1.0, 0), (0.0, 0)],
#  [(2.0, 0), (2.5, 2), (3.0, 0), (2.0, 0)],
#  [(4.0, 0), (4.5, 2), (5.0, 0), (4.0, 0)],
#  [(6.0, 0), (6.5, 2), (7.0, 0), (6.0, 0)],
#  [(8.0, 0), (8.5, 2), (9.0, 0), (8.0, 0)],
#  [(10.0, 0), (10.5, 2), (11.0, 0), (10.0, 0)],
#  [(12.0, 0), (12.5, 2), (13.0, 0), (12.0, 0)],
#  [(14.0, 0), (14.5, 2), (15.0, 0), (14.0, 0)],
#  [(16.0, 0), (16.5, 2), (17.0, 0), (16.0, 0)],
#  [(18.0, 0), (18.5, 2), (19.0, 0), (18.0, 0)]]

# %% [markdown]
# 2.3

# %%
def gen_hexagon(n = 10):
    #((6.75, 0), (6, 2.0), (6.75, 4), (8.25, 4), (9, 2.0), (8.25, 0))
    o = []
    x = np.array([6.75, 6, 6.75, 8.25, 9, 8.25, 8.25])
    y = np.array([0, 2, 4, 4, 2, 0, 0])
    for i in range(n):
        plt.plot(x, y)
        plt.fill_between(x, y)
        o.append(list(zip(x, y)))
        x += 5
    plt.show
    return o
    
gen_hexagon()
# Out:
# [[(6.75, 0), (6.0, 2), (6.75, 4), (8.25, 4), (9.0, 2), (8.25, 0), (8.25, 0)],
#  [(11.75, 0),
#   (11.0, 2),
#   (11.75, 4),
#   (13.25, 4),
#   (14.0, 2),
#   (13.25, 0),
#   (13.25, 0)],
#  [(16.75, 0),
#   (16.0, 2),
#   (16.75, 4),
#   (18.25, 4),
#   (19.0, 2),
#   (18.25, 0),
#   (18.25, 0)],
#  [(21.75, 0),
#   (21.0, 2),
#   (21.75, 4),
#   (23.25, 4),
#   (24.0, 2),
#   (23.25, 0),
#   (23.25, 0)],
#  [(26.75, 0),
#   (26.0, 2),
#   (26.75, 4),
#   (28.25, 4),
#   (29.0, 2),
#   (28.25, 0),
#   (28.25, 0)],
#  [(31.75, 0),
#   (31.0, 2),
#   (31.75, 4),
#   (33.25, 4),
#   (34.0, 2),
#   (33.25, 0),
#   (33.25, 0)],
#  [(36.75, 0),
#   (36.0, 2),
#   (36.75, 4),
#   (38.25, 4),
#   (39.0, 2),
#   (38.25, 0),
#   (38.25, 0)],
#  [(41.75, 0),
#   (41.0, 2),
#   (41.75, 4),
#   (43.25, 4),
#   (44.0, 2),
#   (43.25, 0),
#   (43.25, 0)],
#  [(46.75, 0),
#   (46.0, 2),
#   (46.75, 4),
#   (48.25, 4),
#   (49.0, 2),
#   (48.25, 0),
#   (48.25, 0)],
#  [(51.75, 0),
#   (51.0, 2),
#   (51.75, 4),
#   (53.25, 4),
#   (54.0, 2),
#   (53.25, 0),
#   (53.25, 0)]]

# %% [markdown]
# 2.4

# %% [markdown]
# 3.1

# %%
def tr_translate(n = 10):
    o = []
    x = np.array([0, 0, 1, 1, 0])
    y = np.array([0, 2, 2, 0, 0])
    plt.plot(x, y, x, -y + 5)
    plt.show()
    return o
    
tr_translate()
# Out:
# []

# %% [markdown]
# 3.2

# %%
def tr_rotate(n = 10):
    o = []
    x = np.array([0, 0, 1, 1, 0])
    y = np.array([0, 2, 2, 0, 0])
    plt.plot(x, y)
    plt.show()
    return o
    
tr_rotate()
# Out:
# []

# %% [markdown]
# 3.3

# %%
def tr_symmetry(n = 10):
    o = []
    x = np.array([0, 0, 1, 1, 0])
    y = np.array([0, 2, 2, 0, 0])
    plt.plot(x, y, -x, -y)
    plt.show()
    return o
    
tr_symmetry()
# Out:
# []

# %% [markdown]
# 3.4

# %%
def gen_rectangle(n = 10):
    o = []
    x = np.array([0, 0, 1, 1, 0])
    y = np.array([0, 2, 2, 0, 0])
    plt.plot(x + 1, y + 1)
    plt.fill_between(x, y)
    x += 2
    plt.show()
    return o
    
gen_rectangle()
# Out:
# []
